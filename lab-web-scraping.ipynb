# %% [markdown]
# # Lab | Web Scraping

# %% [markdown]
# Welcome to the IMDb Web Scraping Adventure Lab!
#
# **Objective**
#
# In this lab, we will embark on a mission to unearth valuable insights from the vast sea of data available on IMDb, one of the largest online databases of movie, TV, and celebrity information. As budding data scientists and business analysts, you have been tasked to scrape a specific subset of data from IMDb to assist film production companies in understanding the landscape of highly-rated movies in a defined time period. Your insights will potentially influence the making of the next netflix movie!
#
# **Background**
#
# In a world where data has become the new currency, businesses are leveraging big data to make informed decisions that drive success and profitability. The entertainment industry, being no exception, utilizes data analytics to comprehend market trends, audience preferences, and the performance of films based on various parameters such as director, genre, stars involved, etc. IMDb stands as a goldmine of such data, offering intricate details of almost every movie ever made.
#
# **Task**
#
# Your task is to create a Python script using `BeautifulSoup` and `pandas` to scrape IMDb movie data based on user ratings and release dates. This script should be able to filter movies with ratings above a certain threshold and within a specified date range.
#
# **Expected Outcome**
#
# - A function named `scrape_imdb` that takes four parameters: `title_type`,`user_rating`, `start_date`, and `end_date`.
# - The function should return a DataFrame with the following columns:
#   - **Movie Nr**: The number representing the movie’s position in the list.
#   - **Title**: The title of the movie.
#   - **Year**: The year the movie was released.
#   - **Rating**: The IMDb rating of the movie.
#   - **Runtime (min)**: The duration of the movie in minutes.
#   - **Genre**: The genre of the movie.
#   - **Description**: A brief description of the movie.
#   - **Director**: The director of the movie.
#   - **Stars**: The main stars of the movie.
#   - **Votes**: The number of votes the movie received.
#   - **Gross ($M)**: The gross earnings of the movie in millions of USD.
#
# You will execute this script to scrape data for movies with the Title Type `Feature Film` that have a user rating of `7.5 and above` and were released between `January 1, 1990, and December 31, 1992`.
#
# Remember to experiment with different title types, dates and ratings to ensure your code is versatile and can handle various searches effectively!
#
# **Resources**
#
# - [Beautiful Soup Documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Pandas Documentation](https://pandas.pydata.org/pandas-docs/stable/index.html)
# - [IMDb Advanced Search](https://www.imdb.com/search/title/)

# %% [markdown]
# **Hint**
#
# Your first mission is to familiarize yourself with the IMDb advanced search page. Head over to [IMDb advanced search](https://www.imdb.com/search/title/) and input the following parameters, keeping all other fields to their default values or blank:
#
# - **Title Type**: Feature film
# - **Release date**: From 1990 to 1992 (Note: You don't need to specify the day and month)
# - **User Rating**: 7.5 to -
#
# Upon searching, you'll land on a page showcasing a list of movies, each displaying vital details such as the title, release year, and crew information. Your task is to scrape this treasure trove of data.
#
# Carefully examine the resulting URL and construct your own URL to include all the necessary parameters for filtering the movies.

# %% [markdown]
# ---
#
# **Best of luck! Immerse yourself in the world of movies and may the data be with you!**

# %% [markdown]
# **Important note**:
#
# In the fast-changing online world, websites often get updates and make changes. When you try this lab, the IMDb website might be different from what we expect.
#
# If you run into problems because of these changes, like new rules or things that stop you from getting data, don't worry! Instead, get creative.
#
# You can choose another website that interests you and is good for scraping data. Websites like Wikipedia or The New York Times are good options. The main goal is still the same: get useful data and learn how to scrape it from a website that you find interesting. It's a chance to practice your web scraping skills and explore a source of information you like.

# %%
import requests

import pandas as pd

url = "https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,"
response = requests.get(url)
response

from bs4 import BeautifulSoup

soup = BeautifulSoup(response.content, "html.parser")

# %%
def scrape_imdb(soup):
    movie_number_list = []
    title_list = []
    year_list = []
    rating_list = []
    runtime_list = []
    genre_list =[]
    description_list = []
    director_list = []
    stars_list = []
    votes_list = []
    gross_list = []
    
    films = soup.find_all('div', class_= 'lister-item-content')
    
    for film in films:
        
        movie_number = film.find('span', class_= 'lister-item-index unbold text-primary').text.strip()
        movie_number_list.append(movie_number)
        
        title = film.find('a').text.strip()
        title_list.append(title)
        
        year = film.find('span', class_= 'lister-item-year text-muted unbold').text.replace('(','').replace(')','').strip()
        year_list.append(year)
        
        rating = film.find('strong').text.strip()
        rating_list.append(rating)
        
        runtime = film.find('span', class_= 'runtime').text.replace(' min','').strip()
        runtime_list.append(runtime)
        
        genre = film.find('span', class_= 'genre').text.strip()
        genre_list.append(genre)
        
        description = film.select('p', class_='text-muted')[1].text.strip()
        description_list.append(description)
        
        director = film.select('p')[2].text.split('\n')
        director_list.append(director[2])
        
        stars = film.select('p')[2].text.split('\n')
        stars_list.append(stars[5:9])
        
        votes = film.select('p')[3].text.split('\n')
        votes_list.append(votes[2])
        
        gross = film.select('p')[3].text.split('\n')
        gross_list.append(gross[-2])
        
        df = pd.DataFrame({'Number in List':movie_number_list,
                           'Name of Film':title_list,
                           'Year of Release':year_list,
                           'IMDb Rating':rating_list,
                           'Runtime':runtime_list,
                           'Genres':genre_list,
                           'Description':description_list,
                           'Director':director_list,
                           'Starring':stars_list,
                           'Public Votes':votes_list,
                           'Gross Revenue':gross_list})
    
    return df

# %%
x = scrape_imdb(soup)
x
# Out:
#    Number in List                        Name of Film Year of Release  \
# 0              1.                      Les affranchis            1990
# 1              2.              Le Silence des agneaux            1991
# 2              3.  Terminator 2 : Le jugement dernier            1991
# 3              4.                    Mon cousin Vinny            1992
# 4              5.                      Reservoir Dogs            1992
# 5              6.           Maman, j'ai raté l'avion!            1990
# 6              7.                              Misery            1990
# 7              8.             Le dernier des Mohicans            1992
# 8              9.               Le parrain, 3e partie            1990
# 9             10.                        Total Recall            1990
# 10            11.           Edward aux mains d'argent            1990
# 11            12.                         Impitoyable            1992
# 12            13.                Des hommes d'honneur            1992
# 13            14.              Le Temps d'un week-end            1992
# 14            15.                Danse avec les loups            1990
# 15            16.                             Aladdin            1992
# 16            17.                                 JFK            1991
# 17            18.   Boyz'n the Hood, la loi de la rue            1991
# 18            19.                 La Belle et la Bête            1991
# 19            20.                     Thelma & Louise            1991
# 20            21.      À la poursuite d'Octobre Rouge            1990
# 21            22.                             L'éveil            1990
# 22            23.          Beignets de tomates vertes            1991
# 23            24.                           Braindead            1992
# 24            25.                           Glengarry            1992
# 25            26.                             Chaplin            1992
# 26            27.                           Malcolm X            1992
# 27            28.        Fisher King - Le roi pêcheur            1991
# 28            29.                   Miller's Crossing            1990
# 29            30.            Des souris et des hommes            1992
# 30            31.                          The Player            1992
# 31            32.                         Porco Rosso            1992
# 32            33.                     Les Commitments            1991
# 33            34.                  Adieu ma concubine            1992
# 34            35.                         Barton Fink            1991
# 35            36.                   La Belle Noiseuse            1991
# 36            37.                        Delicatessen            1991
# 37            38.                      Night on Earth            1991
# 38            39.                     À toute épreuve            1992
# 39            40.                               Rêves            1990
# 40            41.          La double vie de Véronique            1991
# 41            42.          Souvenirs, goutte à goutte            1991
# 42            43.               A Brighter Summer Day            1991
# 43            44.                            Close-Up            1990
# 44            45.               Épouses et concubines            1991
# 45            46.                 The Five Heartbeats            1991
# 46            47.                  Cyrano de Bergerac            1990
# 47            48.               Noël chez les Muppets            1992
# 48            49.                              Europa            1991
# 49            50.                     Maris et femmes            1992
#
#    IMDb Rating Runtime                        Genres  \
# 0          8.7     145       Biography, Crime, Drama
# 1          8.6     118        Crime, Drama, Thriller
# 2          8.6     137                Action, Sci-Fi
# 3          7.6     120                 Comedy, Crime
# 4          8.3      99               Crime, Thriller
# 5          7.7     103                Comedy, Family
# 6          7.8     107               Drama, Thriller
# 7          7.7     112      Action, Adventure, Drama
# 8          7.6     162                  Crime, Drama
# 9          7.5     113     Action, Adventure, Sci-Fi
# 10         7.9     105       Drama, Fantasy, Romance
# 11         8.2     130                Drama, Western
# 12         7.7     138               Drama, Thriller
# 13         8.0     156                         Drama
# 14         8.0     181     Adventure, Drama, Western
# 15         8.0      90  Animation, Adventure, Comedy
# 16         8.0     189      Drama, History, Thriller
# 17         7.8     112                  Crime, Drama
# 18         8.0      84    Animation, Family, Fantasy
# 19         7.6     130       Adventure, Crime, Drama
# 20         7.5     135   Action, Adventure, Thriller
# 21         7.8     121              Biography, Drama
# 22         7.7     130                         Drama
# 23         7.5     104       Comedy, Fantasy, Horror
# 24         7.7     100         Crime, Drama, Mystery
# 25         7.5     143      Biography, Comedy, Drama
# 26         7.7     202     Biography, Drama, History
# 27         7.5     137        Comedy, Drama, Fantasy
# 28         7.7     115        Crime, Drama, Thriller
# 29         7.5     115                Drama, Western
# 30         7.5     124          Comedy, Crime, Drama
# 31         7.7      94  Animation, Adventure, Comedy
# 32         7.6     118          Comedy, Drama, Music
# 33         8.1     171         Drama, Music, Romance
# 34         7.6     116       Comedy, Drama, Thriller
# 35         7.5     238                         Drama
# 36         7.5      99                 Comedy, Crime
# 37         7.7     129                 Comedy, Drama
# 38         7.7     128       Action, Crime, Thriller
# 39         7.7     119                Drama, Fantasy
# 40         7.7      98         Drama, Fantasy, Music
# 41         7.6     119     Animation, Drama, Romance
# 42         8.2     237         Crime, Drama, Romance
# 43         8.2      98       Biography, Crime, Drama
# 44         8.1     125                Drama, Romance
# 45         7.5     121                  Drama, Music
# 46         7.5     137        Comedy, Drama, History
# 47         7.7      85         Comedy, Drama, Family
# 48         7.6     112               Drama, Thriller
# 49         7.5     108        Comedy, Drama, Romance
#
#                                           Description              Director  \
# 0   The story of Henry Hill and his life in the ma...       Martin Scorsese
# 1   A young F.B.I. cadet must receive the help of ...        Jonathan Demme
# 2   A cyborg, identical to the one who failed to k...         James Cameron
# 3   Two New Yorkers accused of murder in rural Ala...         Jonathan Lynn
# 4   When a simple jewelry heist goes horribly wron...     Quentin Tarantino
# 5   An eight-year-old troublemaker, mistakenly lef...        Chris Columbus
# 6   After a famous author is rescued from a car cr...            Rob Reiner
# 7   Three trappers protect the daughters of a Brit...          Michael Mann
# 48  [Barbara Sukowa, , Jean-Marc Barr, , Udo Kier,...       22,575
# 49  [Woody Allen, , Mia Farrow, , Sydney Pollack, ...       30,506
#
#    Gross Revenue
# 0        $46.84M
# 1       $130.74M
# 2       $204.84M
# 3        $52.93M
# 4         $2.83M
# 5       $285.76M
# 6        $61.28M
# 7        $75.51M
# 8        $66.67M
# 9       $119.39M
# 10       $56.36M
# 11      $101.16M
# 12      $141.34M
# 13       $63.90M
# 14      $184.21M
# 15      $217.35M
# 16       $70.41M
# 17       $57.50M
# 18      $218.97M
# 19       $45.36M
# 20      $122.01M
# 21       $52.10M
# 22       $82.42M
# 23        $0.24M
# 24       $10.73M
# 25        $9.49M
# 26       $48.17M
# 27       $41.90M
# 28        $5.08M
# 29        $5.10M
# 30       $21.71M
# 31        96,772
# 32       $14.92M
# 33        $5.22M
# 34        $6.15M
# 35        $0.41M
# 36        $1.79M
# 37        $2.02M
# 38        52,837
# 39        $1.96M
# 40        $2.00M
# 41        $0.45M
# 42        11,972
# 43        $0.00M
# 44        $2.60M
# 45        $8.75M
# 46       $15.14M
# 47       $27.28M
# 48        $1.01M
# 49       $10.56M

# %%
#main > div > div.lister.list.detail.sub-list > div > div:nth-child(1) > div.lister-item-content > h3 > a

#main > div > div.lister.list.detail.sub-list > div > div:nth-child(2) > div.lister-item-content > h3 > a

#main > div > div.lister.list.detail.sub-list > div > div:nth-child(1) > div.lister-item-content > p:nth-child(5)

lister-item-index unbold text-primary
# Out:
#   Cell In[96], line 7
#     lister-item-index unbold text-primary
#                       ^
# SyntaxError: invalid syntax

# %%
def extract_bike_info(soup):
    
    bicycle_names = []
    prices = []
    URL_dets = []
    URL_img = []
    
    components = soup.find_all('article', class_='de-ProductTile')
    #components = soup.find_all('section', class_='de-ProductTile-info')

    
    for component in components:
    # Extract bicycle name
        bike_name = component.find('h4', class_='de-ProductTile-title').text.strip()
        bicycle_names.append(bike_name)

    # Extract price
        price = component.find('span', class_='js-de-ProductTile-currentPrice').text.strip().replace("$", "")
        prices.append(price)
        
    # Extract URL for the product details
        link_bike = component.find('a', class_='de-u-linkClean js-de-ProductTile-link')
        URL_dets.append('http://decathlon.com' + link_bike.get('href'))
        
    # Extract URL for images
        link_image = component.find('img', itemprop='image').get('data-src')
        URL_img.append(link_image[2:])
        
    df = pd.DataFrame({'Bicycle Names':bicycle_names, 'Bicycle Prices':prices, 'Links for Bike Details':URL_dets, 'Links for Bike Images':URL_img})
    
    return df

# %% [markdown]
# ## BONUS
#
# The search results span multiple pages, housing a total of 631 movies in our example with each page displaying 50 movies at most. To scrape data seamlessly from all pages, you'll need to dive deep into the structure of the URLs generated with each "Next" click.
#
# Take a close look at the following URLs:
# - First page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,
#   ```
# - Second page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=51&ref_=adv_nxt
#   ```
# - Third page:
#   ```
#   https://www.imdb.com/search/title/?title_type=feature&release_date=1990-01-01,1992-12-31&user_rating=7.5,&start=101&ref_=adv_nxt
#   ```
#
# You should notice a pattern. There is a `start` parameter incrementing by 50 with each page, paired with a constant `ref_` parameter holding the value "adv_nxt".
#
# Modify your script so it's capable of iterating over all available pages to fetch data on all the 631 movies (631 is the total number of movies in the proposed example).

# %%
# Your solution goes here
